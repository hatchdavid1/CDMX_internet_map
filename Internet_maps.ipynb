# %%
import pandas as pd
import numpy as np
import requests
import json
import folium

# %%
resp = requests.get('https://datos.cdmx.gob.mx/api/records/1.0/search/?dataset=ubicacion-acceso-gratuito-internet-wifi-c5&q=&rows=10000&facet=colonia&facet=alcaldia&facet=boton&facet=altavoz&facet=tipo_de_poste')
results=resp.json()
#data=pd.DataFrame(results)
#data.head()

# %%
results.keys()
# Out:
# dict_keys(['nhits', 'parameters', 'records', 'facet_groups'])

# %%
data = results.get('records')
newdict={}
for k,v in [(key,d[key]) for d in data for key in d]:
      if k not in newdict: newdict[k]=[v]
      else: newdict[k].append(v)

# %%
fields = newdict.get('fields')
df=pd.DataFrame(results)
#data.head()
# Out:
# {'nhits': 13694,
#  'parameters': {'dataset': 'ubicacion-acceso-gratuito-internet-wifi-c5',
#   'timezone': 'UTC',
#   'rows': 10000,
#   'start': 0,
#   'format': 'json',
#   'facet': ['colonia', 'alcaldia', 'boton', 'altavoz', 'tipo_de_poste']},
#  'records': [{'datasetid': 'ubicacion-acceso-gratuito-internet-wifi-c5',
#    'recordid': 'f0152d04348f76eb3ab4cf91bc28a3641b8b9ed6',
#    'fields': {'latitud': 19.371661,
#     'colonia': 'TORRES DE MIXCOAC',
#     'alcaldia': 'ALVARO OBREGON',
#     'geopoint': [19.371661, -99.191936],
#     'boton': 'SIN BOTON',
#     'tipo_de_poste': '9m',
#     'esquina': 'ENTRE C. ROSA TREPADORA Y C. DR. S. GONZALEZ HERREJON',
#     'altavoz': 'CON ALTAVOZ',
#     'direccion': 'BOULEVARD ADOLFO LOPEZ MATEOS',
#     'longitud': -99.191936,
#     'estatus_conectividad': 'WIFI GRATUITO_ACTIVO'},
#    'geometry': {'type': 'Point', 'coordinates': [-99.191936, 19.371661]},
#    'record_timestamp': '2020-10-06T22:30:28.636000+00:00'},
# ...

# %%
nested_cols=['fields', 'geometry']
flat=flatten(data, nested_cols)
flat.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-eb3b1ba90654> in <module>
#       1 nested_cols=['fields', 'geometry']
# ----> 2 flat=flatten(data, nested_cols)
#       3 flat.head()
#
# <ipython-input-30-2abb1385e091> in flatten(data, cols)
#       1 def flatten(data, cols):
#       2     for c in cols:
# ----> 3         fl=pd.DataFrame(dict(data[c])).T
#       4         cols=[str(col) for col in fl.columns]
#       5         fl.columns=[c+'_'+name for name in cols]
#
# TypeError: list indices must be integers or slices, not str

# %%
records
# Out:
# [{'datasetid': 'ubicacion-acceso-gratuito-internet-wifi-c5',
#   'recordid': 'f0152d04348f76eb3ab4cf91bc28a3641b8b9ed6',
#   'fields': {'latitud': 19.371661,
#    'colonia': 'TORRES DE MIXCOAC',
#    'alcaldia': 'ALVARO OBREGON',
#    'geopoint': [19.371661, -99.191936],
#    'boton': 'SIN BOTON',
#    'tipo_de_poste': '9m',
#    'esquina': 'ENTRE C. ROSA TREPADORA Y C. DR. S. GONZALEZ HERREJON',
#    'altavoz': 'CON ALTAVOZ',
#    'direccion': 'BOULEVARD ADOLFO LOPEZ MATEOS',
#    'longitud': -99.191936,
#    'estatus_conectividad': 'WIFI GRATUITO_ACTIVO'},
#   'geometry': {'type': 'Point', 'coordinates': [-99.191936, 19.371661]},
#   'record_timestamp': '2020-10-06T22:30:28.636000+00:00'},
#  {'datasetid': 'ubicacion-acceso-gratuito-internet-wifi-c5',
#   'recordid': 'e708e6e683d4d7d06757aa47c2ceff64380d219a',
#   'fields': {'latitud': 19.372175,
#    'colonia': 'MOLINO DE ROSAS',
#    'alcaldia': 'ALVARO OBREGON',
#    'geopoint': [19.372175, -99.193498],
# ...
